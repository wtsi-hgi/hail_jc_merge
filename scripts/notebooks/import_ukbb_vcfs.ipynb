# %%
from hail import Table
import os
import pprint
from pprint import pformat
import argparse
import hail as hlh
import pandas as pd
import numpy as np
import pyspark
from pprint import pformat
import json
import sys
import re
from pathlib import Path
import logging
from typing import Any, Counter, List, Optional, Tuple, Union, Dict,Set
import uuid
import json
from matplotlib import pyplot as plt
from typing import Any, Counter, List, Optional, Tuple, Union,Dict,Set
from hail.plot import show, output_notebook
from gnomad.utils.plotting import *
from typing import Set, Tuple
from bokeh.palettes import d3  # pylint: disable=no-name-in-module
from bokeh.models import Plot, Row, Span, NumeralTickFormatter, LabelSet
import warnings; 
warnings.simplefilter('ignore')
tmp_dir = "hdfs://spark-master:9820/"
temp_dir = "file:///home/ubuntu/data/tmp"
#plot_dir = "/home/ubuntu/data/tmp"
plot_dir="/lustre/scratch123/teams/hgi/mercury/megaWES-variantqc"
lustre_dir = "file:///lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge"
import_lustre_dir="file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge"
sc = pyspark.SparkContext()
hadoop_config = sc._jsc.hadoopConfiguration()
hadoop_config.set("fs.s3a.access.key", "8YY584J59H7Q6AVKHSU8")
hadoop_config.set("fs.s3a.secret.key", "P8vePa7JUvxKXX2me9ti1cGujgYWMoimAwx4mMlM")
hadoop_config.set("fs.gs.impl", "com.google.cloud.hadoop.fs.gcs.GoogleHadoopFileSystem")
hadoop_config.set("fs.AbstractFileSystem.gs.impl", "com.google.cloud.hadoop.fs.gcs.GoogleHadoopFS")
hl.init(sc=sc, tmp_dir=lustre_dir, local_tmpdir=lustre_dir, default_reference="GRCh38")
output_notebook()
# Out:
# pip-installed Hail requires additional configuration options in Spark referring
#   to the path to the Hail Python module directory HAIL_DIR,
#   e.g. /path/to/python/site-packages/hail:
#     spark.jars=HAIL_DIR/hail-all-spark.jar
#     spark.driver.extraClassPath=HAIL_DIR/hail-all-spark.jar
#     spark.executor.extraClassPath=./hail-all-spark.jarRunning on Apache Spark version 2.4.7
# SparkUI available at http://spark-master:4040
# Welcome to
#      __  __     <>__
#     / /_/ /__  __/ /
#    / __  / _ `/ / /
#   /_/ /_/\_,_/_/_/   version 0.2.62-84fa81b9ea3d
# LOGGING: writing to /home/ubuntu/data/scripts/hail-20211110-1343-0.2.62-84fa81b9ea3d.log
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
import_lustre_dir="file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb"
lustre_dir = "file:///lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb"
path=import_lustre_dir

objects = hl.utils.hadoop_ls(path)
vcf_header=f"{lustre_dir}/vcf_header.txt"
#print(objects)
print("Reading vcf filenames")
    #vcfs = [vcf["path"] for vcf in objects if (vcf["path"].startswith(f"{s3location_input}chr"+chromosome+"_") and vcf["path"].endswith(".vcf.gz"))]
vcfs = [vcf["path"] for vcf in objects if (vcf["path"].startswith(f"{path}/ukb") and vcf["path"].endswith(".vcf.gz"))]

print(vcfs)

mt = hl.import_vcf(vcfs, array_elements_required=False, 
                       force_bgz=True, header_file= vcf_header)
print("Imported vcf files")
   

mt.write(f"{lustre_dir}/ukbb_MAF_0_01.mt")
# Out:
# Reading vcf filenames
# ['file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c22_b10_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c4_b29_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c20_b4_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_cX_b14_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c7_b27_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c17_b54_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c1_b3_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c2_b4_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c1_b2_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c11_b34_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c5_b41_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c6_b22_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c1_b35_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c8_b12_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c19_b17_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c1_b83_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c8_b29_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c3_b9_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c12_b17_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c12_b23_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c11_b13_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c19_b44_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c3_b49_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c12_b38_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c6_b30_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c12_b51_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c16_b0_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c6_b18_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c8_b2_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c6_b2_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c14_b27_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c1_b87_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c6_b3_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukb23156_c6_b31_v1.vcf.gz', 'file:/lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_uk ...
# 2021-11-10 13:45:13 Hail: WARN: Loading user-provided header file. The sample IDs, INFO fields, and FORMAT fields were not checked for agreement with input data.
# Imported vcf files
# 2021-11-10 13:45:54 Hail: INFO: Coerced sorted dataset
# 2021-11-10 13:45:54 Hail: INFO: Coerced dataset with out-of-order partitions.
# 2021-11-10 13:51:54 Hail: INFO: wrote matrix table with 150968 rows and 200643 columns in 1020 partitions to file:///lustre/scratch123/mdt1/projects/wes_jc_ukb_ibd/hail_merge/vcf_files/maf_001_ukb/ukbb_MAF_0_01.mt
#     Total size: 131.68 GiB
#     * Rows/entries: 131.68 GiB
#     * Columns: 1.13 MiB
#     * Globals: 11.00 B
#     * Smallest partition: 23 rows (10.86 MiB)
#     * Largest partition:  253 rows (231.71 MiB)
